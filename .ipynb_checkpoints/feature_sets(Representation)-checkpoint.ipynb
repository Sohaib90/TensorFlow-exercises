# %%
import math

from IPython import display
from matplotlib import cm
from matplotlib import gridspec
from matplotlib import pyplot as plt
import numpy as np
import pandas as pd
from sklearn import metrics
import tensorflow as tf
from tensorflow.python.data import Dataset

tf.logging.set_verbosity(tf.logging.ERROR)
pd.options.display.max_rows = 10
pd.options.display.float_format = '{:.1f}'.format

california_housing_dataframe = pd.read_csv("https://storage.googleapis.com/mledu-datasets/california_housing_train.csv", sep=",")

california_housing_dataframe = california_housing_dataframe.reindex(
    np.random.permutation(california_housing_dataframe.index))

# %%
def preprocess_features(california_housing_dataframe):
    input_feature = california_housing_dataframe[["latitude",
     "longitude",
     "housing_median_age",
     "total_rooms",
     "total_bedrooms",
     "population",
     "households",
     "median_income"]]
    selected_features = input_feature.copy()
    selected_features["rooms_per_person"] = california_housing_dataframe["total_rooms"] / california_housing_dataframe["population"]
    return selected_features

def preprocess_targets(california_housing_dataframe):
    output_targets = pd.DataFrame()
    output_targets["median_house_value"] = (california_housing_dataframe["median_house_value"]/1000.0)
    return output_targets

def construct_feature_columns(input_feature):
    return set([tf.feature_column.numeric_column(my_feature) for my_feature in input_feature])

# %%
# Choose the first 12000 (out of 17000) examples for training.
training_examples = preprocess_features(california_housing_dataframe.head(12000))
training_targets = preprocess_targets(california_housing_dataframe.head(12000))

# Choose the last 5000 (out of 17000) examples for validation.
validation_examples = preprocess_features(california_housing_dataframe.tail(5000))
validation_targets = preprocess_targets(california_housing_dataframe.tail(5000))

# Double-check that we've done the right thing.
print ("Training examples summary:")
display.display(training_examples.describe())
print ("Validation examples summary:")
display.display(validation_examples.describe())

print ("Training targets summary:")
display.display(training_targets.describe())
print ("Validation targets summary:")
display.display(validation_targets.describe())
# Out:
# Training examples summary:
#        latitude  longitude  housing_median_age  total_rooms  total_bedrooms  \
# count   12000.0    12000.0             12000.0      12000.0         12000.0
# mean       35.6     -119.6                28.7       2644.3           539.1
# std         2.1        2.0                12.6       2197.8           426.7
# min        32.5     -124.3                 1.0          2.0             1.0
# 25%        33.9     -121.8                18.0       1458.0           295.0
# 50%        34.3     -118.5                29.0       2126.5           431.0
# 75%        37.7     -118.0                37.0       3144.2           646.2
# max        42.0     -114.3                52.0      37937.0          5471.0
#
#        population  households  median_income  rooms_per_person
# count     12000.0     12000.0        12000.0           12000.0
# mean       1428.6       500.8            3.9               2.0
# std        1152.4       388.7            1.9               1.1
# min           3.0         1.0            0.5               0.0
# 25%         784.0       281.0            2.6               1.5
# 50%        1160.0       407.0            3.5               1.9
# 75%        1717.0       603.0            4.8               2.3
# max       35682.0      5189.0           15.0              55.2
# Validation examples summary:
#        latitude  longitude  housing_median_age  total_rooms  total_bedrooms  \
# count    5000.0     5000.0              5000.0       5000.0          5000.0
# mean       35.6     -119.5                28.3       2642.1           540.2
# std         2.1        2.0                12.6       2136.6           408.9
# min        32.5     -124.3                 1.0         18.0             3.0
# 25%        33.9     -121.8                18.0       1470.8           300.0
# 50%        34.2     -118.5                29.0       2130.5           442.0
# 75%        37.7     -118.0                37.0       3165.0           654.0
# max        42.0     -114.6                52.0      32627.0          6445.0
#
#        population  households  median_income  rooms_per_person
# count      5000.0      5000.0         5000.0            5000.0
# mean       1431.9       502.2            3.9               2.0
# std        1137.0       374.3            1.9               1.3
# min           8.0         4.0            0.5               0.1
# 25%         802.0       284.0            2.6               1.5
# 50%        1183.0       414.0            3.5               1.9
# 75%        1730.0       608.0            4.8               2.3
# max       28566.0      6082.0           15.0              52.0
# Training targets summary:
#        median_house_value
# count             12000.0
# mean                207.4
# std                 116.3
# min                  15.0
# 25%                 118.8
# 50%                 179.8
# 75%                 265.8
# max                 500.0
# Validation targets summary:
#        median_house_value
# count              5000.0
# mean                207.0
# std                 115.2
# min                  22.5
# 25%                 121.4
# 50%                 181.8
# 75%                 262.5
# max                 500.0

# %%
#Co relation matrix shows pairwise co relation, between each feature and target as well as each featue and other features

correlation_dataframe = training_examples.copy()
correlation_dataframe["target"] = training_targets["median_house_value"]

correlation_dataframe.corr()
# Out:
#                     latitude  longitude  housing_median_age  total_rooms  \
# latitude                 1.0       -0.9                 0.0         -0.0
# longitude               -0.9        1.0                -0.1          0.0
# housing_median_age       0.0       -0.1                 1.0         -0.4
# total_rooms             -0.0        0.0                -0.4          1.0
# total_bedrooms          -0.1        0.1                -0.3          0.9
# population              -0.1        0.1                -0.3          0.9
# households              -0.1        0.1                -0.3          0.9
# median_income           -0.1       -0.0                -0.1          0.2
# rooms_per_person         0.1       -0.1                -0.1          0.1
# target                  -0.1       -0.0                 0.1          0.1
#
#                     total_bedrooms  population  households  median_income  \
# latitude                      -0.1        -0.1        -0.1           -0.1
# longitude                      0.1         0.1         0.1           -0.0
# housing_median_age            -0.3        -0.3        -0.3           -0.1
# total_rooms                    0.9         0.9         0.9            0.2
# total_bedrooms                 1.0         0.9         1.0           -0.0
# population                     0.9         1.0         0.9           -0.0
# households                     1.0         0.9         1.0            0.0
# median_income                 -0.0        -0.0         0.0            1.0
# rooms_per_person               0.1        -0.1        -0.0            0.2
# target                         0.0        -0.0         0.1            0.7
#
#                     rooms_per_person  target
# latitude                         0.1    -0.1
# longitude                       -0.1    -0.0
# housing_median_age              -0.1     0.1
# total_rooms                      0.1     0.1
# total_bedrooms                   0.1     0.0
# population                      -0.1    -0.0
# households                      -0.0     0.1
# median_income                    0.2     0.7
# rooms_per_person                 1.0     0.2
# target                           0.2     1.0

# %%
def my_input_fn(features, targets, batch_size=1, shuffle=True, num_epochs=None):
    """Trains a linear regression model.
  
    Args:
      features: pandas DataFrame of features
      targets: pandas DataFrame of targets
      batch_size: Size of batches to be passed to the model
      shuffle: True or False. Whether to shuffle the data.
      num_epochs: Number of epochs for which data should be repeated. None = repeat indefinitely
    Returns:
      Tuple of (features, labels) for next data batch
    """
    
    # Convert pandas data into a dict of np arrays.
    features = {key:np.array(value) for key,value in dict(features).items()}                                           
    
    # Construct a dataset, and configure batching/repeating.
    ds = Dataset.from_tensor_slices((features,targets)) # warning: 2GB limit
    ds = ds.batch(batch_size).repeat(num_epochs)

    # Shuffle the data, if specified.
    if shuffle:
        ds = ds.shuffle(10000)
    
    # Return the next batch of data.
    features, labels = ds.make_one_shot_iterator().get_next()
    return features, labels

# %%
def train_model(
    learning_rate,
    steps,
    batch_size,
    training_examples,
    training_targets,
    validation_examples,
    validation_targets):

    periods = 10
    steps_per_period = steps / periods

      # Create a linear regressor object.
    my_optimizer = tf.train.GradientDescentOptimizer(learning_rate=learning_rate)
    my_optimizer = tf.contrib.estimator.clip_gradients_by_norm(my_optimizer, 5.0)
    linear_regressor = tf.estimator.LinearRegressor(
          feature_columns=construct_feature_columns(training_examples),
          optimizer=my_optimizer
      )

      # Create input functions.
    training_input_fn = lambda: my_input_fn(training_examples, 
                                              training_targets["median_house_value"], 
                                              batch_size=batch_size)
    predict_training_input_fn = lambda: my_input_fn(training_examples, 
                                                      training_targets["median_house_value"], 
                                                      num_epochs=1, 
                                                      shuffle=False)
    predict_validation_input_fn = lambda: my_input_fn(validation_examples, 
                                                        validation_targets["median_house_value"], 
                                                        num_epochs=1, 
                                                        shuffle=False)

      # Train the model, but do so inside a loop so that we can periodically assess
      # loss metrics.
    print ("Training model...")
    print ("RMSE (on training data):")
    training_rmse = []
    validation_rmse = []
    for period in range (0, periods):
        # Train the model, starting from the prior state.
        linear_regressor.train(
            input_fn=training_input_fn,
            steps=steps_per_period,
        )
        # Take a break and compute predictions.
        training_predictions = linear_regressor.predict(input_fn=predict_training_input_fn)
        training_predictions = np.array([item['predictions'][0] for item in training_predictions])

        validation_predictions = linear_regressor.predict(input_fn=predict_validation_input_fn)
        validation_predictions = np.array([item['predictions'][0] for item in validation_predictions])

        # Compute training and validation loss.
        training_root_mean_squared_error = math.sqrt(
            metrics.mean_squared_error(training_predictions, training_targets))
        validation_root_mean_squared_error = math.sqrt(
            metrics.mean_squared_error(validation_predictions, validation_targets))
        # Occasionally print the current loss.
        print("  period %02d : %0.2f" % (period, training_root_mean_squared_error))
        # Add the loss metrics from this period to our list.
        training_rmse.append(training_root_mean_squared_error)
        validation_rmse.append(validation_root_mean_squared_error)
    print ("Model training finished.")


    # Output a graph of loss metrics over periods.
    plt.ylabel("RMSE")
    plt.xlabel("Periods")
    plt.title("Root Mean Squared Error vs. Periods")
    plt.tight_layout()
    plt.plot(training_rmse, label="training")
    plt.plot(validation_rmse, label="validation")
    plt.legend()

    return linear_regressor

# %%
minimal_features = ["median_income","latitude"]

assert minimal_features, "You must select at least one feature!"

minimal_training_examples = training_examples[minimal_features]
minimal_validation_examples = validation_examples[minimal_features]

_= train_model(
    learning_rate=0.01,
    steps=500,
    batch_size=5,
    training_examples=minimal_training_examples,
    training_targets=training_targets,
    validation_examples=minimal_validation_examples,
    validation_targets=validation_targets)
# Out:
# Training model...
# RMSE (on training data):
#   period 00 : 165.93
#   period 01 : 124.22
#   period 02 : 119.08
#   period 03 : 117.63
#   period 04 : 116.00
#   period 05 : 115.74
#   period 06 : 116.58
#   period 07 : 114.83
#   period 08 : 114.74
#   period 09 : 113.95
# Model training finished.

# %%
plt.scatter(training_examples["latitude"], training_targets["median_house_value"])

# %%
#BINNING THE DATA 
LATITUDE_RANGES = zip(range(32, 44), range(33, 45))
print (LATITUDE_RANGES)

def select_and_transform_features(source_df):
    selected_examples = pd.DataFrame()
    selected_examples["median_income"] = source_df["median_income"]
    for r in LATITUDE_RANGES:
        selected_examples["latitude_%d_to_%d" % r] = source_df["latitude"].apply(lambda l: 1.0 if l >= r[0] and l < r[1] else 0.0)
    return selected_examples

selected_training_examples = select_and_transform_features(training_examples)
print(selected_training_examples)
selected_validation_examples = select_and_transform_features(validation_examples)
# Out:
#        median_income
# 12660            2.5
# 16489            5.2
# 1507             3.3
# 1899             2.2
# 1317             4.5
# ...              ...
# 2970             8.4
# 2579             6.3
# 8020             3.5
# 14086            4.2
# 3402             8.9
#
# [5000 rows x 1 columns]

# %%
_ = train_model(
    learning_rate=0.01,
    steps=500,
    batch_size=5,
    training_examples=selected_training_examples,
    training_targets=training_targets,
    validation_examples=selected_validation_examples,
    validation_targets=validation_targets)
# Out:
# Training model...
# RMSE (on training data):
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-34-558d4efa8eaa> in <module>()
#       6     training_targets=training_targets,
#       7     validation_examples=selected_validation_examples,
# ----> 8     validation_targets=validation_targets)
#
# <ipython-input-25-ff24ab1fa85a> in train_model(learning_rate, steps, batch_size, training_examples, training_targets, validation_examples, validation_targets)
#      49
#      50         validation_predictions = linear_regressor.predict(input_fn=predict_validation_input_fn)
# ---> 51         validation_predictions = np.array([item['predictions'][0] for item in validation_predictions])
#      52
#      53         # Compute training and validation loss.
#
# <ipython-input-25-ff24ab1fa85a> in <listcomp>(.0)
#      49
#      50         validation_predictions = linear_regressor.predict(input_fn=predict_validation_input_fn)
# ---> 51         validation_predictions = np.array([item['predictions'][0] for item in validation_predictions])
#      52
#      53         # Compute training and validation loss.
#
# c:\users\sohaib arshad\appdata\local\programs\python\python35\lib\site-packages\tensorflow\python\estimator\estimator.py in predict(self, input_fn, predict_keys, hooks, checkpoint_path)
#     421           input_fn, model_fn_lib.ModeKeys.PREDICT)
#     422       estimator_spec = self._call_model_fn(
# --> 423           features, None, model_fn_lib.ModeKeys.PREDICT, self.config)
#     424       predictions = self._extract_keys(estimator_spec.predictions, predict_keys)
#     425       with training.MonitoredSession(
#
# c:\users\sohaib arshad\appdata\local\programs\python\python35\lib\site-packages\tensorflow\python\estimator\estimator.py in _call_model_fn(self, features, labels, mode, config)
#     723     if 'config' in model_fn_args:
#     724       kwargs['config'] = config
# --> 725     model_fn_results = self._model_fn(features=features, **kwargs)
#     726
#     727     if not isinstance(model_fn_results, model_fn_lib.EstimatorSpec):
#
# c:\users\sohaib arshad\appdata\local\programs\python\python35\lib\site-packages\tensorflow\python\estimator\canned\linear.py in _model_fn(features, labels, mode, config)
#     354           optimizer=optimizer,
#     355           partitioner=partitioner,
# --> 356           config=config)
#     357     super(LinearRegressor, self).__init__(
#     358         model_fn=_model_fn,
#
# c:\users\sohaib arshad\appdata\local\programs\python\python35\lib\site-packages\tensorflow\python\estimator\canned\linear.py in _linear_model_fn(features, labels, mode, head, feature_columns, optimizer, partitioner, config)
#     116     logit_fn = _linear_logit_fn_builder(
#     117         units=head.logits_dimension, feature_columns=feature_columns)
# --> 118     logits = logit_fn(features=features)
#     119
#     120     def _train_op_fn(loss):
#
# c:\users\sohaib arshad\appdata\local\programs\python\python35\lib\site-packages\tensorflow\python\estimator\canned\linear.py in linear_logit_fn(features)
#      68     """
#      69     return feature_column_lib.linear_model(
# ---> 70         features=features, feature_columns=feature_columns, units=units)
#      71
#      72   return linear_logit_fn
#
# c:\users\sohaib arshad\appdata\local\programs\python\python35\lib\site-packages\tensorflow\python\feature_column\feature_column.py in linear_model(features, feature_columns, units, sparse_combiner, weight_collections, trainable, cols_to_vars)
#     437               sparse_combiner=sparse_combiner,
#     438               weight_collections=weight_collections,
# --> 439               trainable=trainable)
#     440         else:
#     441           # This is typically the case for shared_embedding_columns. The
#
# c:\users\sohaib arshad\appdata\local\programs\python\python35\lib\site-packages\tensorflow\python\feature_column\feature_column.py in _create_weighted_sum(column, builder, units, sparse_combiner, weight_collections, trainable)
#    1721   else:
#    1722     return _create_dense_column_weighted_sum(
# -> 1723         column, builder, units, weight_collections, trainable)
#    1724
#    1725
#
# c:\users\sohaib arshad\appdata\local\programs\python\python35\lib\site-packages\tensorflow\python\feature_column\feature_column.py in _create_dense_column_weighted_sum(column, builder, units, weight_collections, trainable)
#    1730       builder,
#    1731       weight_collections=weight_collections,
# -> 1732       trainable=trainable)
#    1733   num_elements = column._variable_shape.num_elements()  # pylint: disable=protected-access
#    1734   batch_size = array_ops.shape(tensor)[0]
#
# c:\users\sohaib arshad\appdata\local\programs\python\python35\lib\site-packages\tensorflow\python\feature_column\feature_column.py in _get_dense_tensor(***failed resolving arguments***)
#    2094     # Feature has been already transformed. Return the intermediate
#    2095     # representation created by _transform_feature.
# -> 2096     return inputs.get(self)
#    2097
#    2098
#
# c:\users\sohaib arshad\appdata\local\programs\python\python35\lib\site-packages\tensorflow\python\feature_column\feature_column.py in get(self, key)
#    1897     column = key
#    1898     logging.debug('Transforming feature_column %s.', column)
# -> 1899     transformed = column._transform_feature(self)  # pylint: disable=protected-access
#    1900     if transformed is None:
#    1901       raise ValueError('Column {} is not supported.'.format(column.name))
#
# c:\users\sohaib arshad\appdata\local\programs\python\python35\lib\site-packages\tensorflow\python\feature_column\feature_column.py in _transform_feature(self, inputs)
#    2062
#    2063   def _transform_feature(self, inputs):
# -> 2064     input_tensor = inputs.get(self.key)
#    2065     if isinstance(input_tensor, sparse_tensor_lib.SparseTensor):
#    2066       raise ValueError(
#
# c:\users\sohaib arshad\appdata\local\programs\python\python35\lib\site-packages\tensorflow\python\feature_column\feature_column.py in get(self, key)
#    1893
#    1894     if not isinstance(key, _FeatureColumn):
# -> 1895       raise ValueError('Feature {} is not in features dictionary.'.format(key))
#    1896
#    1897     column = key
#
# ValueError: Feature latitude_32_to_33 is not in features dictionary.
